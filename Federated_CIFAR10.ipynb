# %%
import torch
from torchvision.datasets import CIFAR10  # Changed from MNIST to CIFAR10
from torch.utils.data import random_split, DataLoader
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# Set matplotlib to inline mode
# %matplotlib inline
plt.rcParams['figure.figsize'] = [5, 5]

# Load CIFAR10 dataset
train_dataset = CIFAR10(root='./data', train=True, download=True, transform=transforms.ToTensor())
test_dataset = CIFAR10(root='./data', train=False, download=True, transform=transforms.ToTensor())

# Split train_dataset into train and dev sets
train_dataset, dev_dataset = random_split(train_dataset, [int(len(train_dataset) * 0.83), int(len(train_dataset) * 0.17)])

# Get sizes of datasets
total_train_size = len(train_dataset)
total_test_size = len(test_dataset)
total_dev_size = len(dev_dataset)

# Number of classes and input dimensions
classes = 10  # CIFAR10 has 10 classes
input_dim = 3 * 32 * 32  # Input dimension for CIFAR10 images (3 channels RGB)

# Other parameters
num_clients = 8
rounds = 30
batch_size = 128
epochs_per_client = 3
learning_rate = 2e-2

# Function to check and set device
def get_device():
    return torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# Function to move data to device
def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

# Custom DataLoader to move batches to device
class DeviceDataLoader(DataLoader):
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device

    def __iter__(self):
        for batch in self.dl:
            yield to_device(batch, self.device)

    def __len__(self):
        return len(self.dl)

# Define the neural network architecture
class FederatedNet(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(3, 20, 5)  # Adjusted for CIFAR10 (3 channels)
        self.conv2 = torch.nn.Conv2d(20, 40, 5)
        self.maxpool = torch.nn.MaxPool2d(2, 2)
        self.flatten = torch.nn.Flatten()
        self.linear = torch.nn.Linear(40 * 5 * 5, 10)  # Adjusted for CIFAR10
        self.non_linearity = torch.nn.functional.relu
        self.track_layers = {'conv1': self.conv1, 'conv2': self.conv2, 'linear': self.linear}

    def forward(self, x_batch):
        out = self.conv1(x_batch)
        out = self.non_linearity(out)
        out = self.maxpool(out)
        out = self.conv2(out)
        out = self.non_linearity(out)
        out = self.maxpool(out)
        out = self.flatten(out)
        out = self.linear(out)
        return out

    def get_track_layers(self):
        return self.track_layers

    def apply_parameters(self, parameters_dict):
        with torch.no_grad():
            for layer_name in parameters_dict:
                self.track_layers[layer_name].weight.data *= 0
                self.track_layers[layer_name].bias.data *= 0
                self.track_layers[layer_name].weight.data += parameters_dict[layer_name]['weight']
                self.track_layers[layer_name].bias.data += parameters_dict[layer_name]['bias']

    def get_parameters(self):
        parameters_dict = dict()
        for layer_name in self.track_layers:
            parameters_dict[layer_name] = {
                'weight': self.track_layers[layer_name].weight.data,
                'bias': self.track_layers[layer_name].bias.data
            }
        return parameters_dict

    def batch_accuracy(self, outputs, labels):
        with torch.no_grad():
            _, predictions = torch.max(outputs, dim=1)
            return torch.tensor(torch.sum(predictions == labels).item() / len(predictions))

    def _process_batch(self, batch):
        images, labels = batch
        outputs = self(images)
        loss = torch.nn.functional.cross_entropy(outputs, labels)
        accuracy = self.batch_accuracy(outputs, labels)
        return (loss, accuracy)

    def fit(self, dataset, epochs, lr, batch_size=128, opt=torch.optim.SGD):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size, shuffle=True), device)
        optimizer = opt(self.parameters(), lr)
        history = []
        for epoch in range(epochs):
            losses = []
            accs = []
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                loss.backward()
                optimizer.step()
                optimizer.zero_grad()
                loss.detach()
                losses.append(loss)
                accs.append(acc)
            avg_loss = torch.stack(losses).mean().item()
            avg_acc = torch.stack(accs).mean().item()
            history.append((avg_loss, avg_acc))
        return history

    def evaluate(self, dataset, batch_size=128):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size), device)
        losses = []
        accs = []
        with torch.no_grad():
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                losses.append(loss)
                accs.append(acc)
        avg_loss = torch.stack(losses).mean().item()
        avg_acc = torch.stack(accs).mean().item()
        return (avg_loss, avg_acc)

# Define a Client class for federated learning
class Client:
    def __init__(self, client_id, dataset):
        self.client_id = client_id
        self.dataset = dataset

    def get_dataset_size(self):
        return len(self.dataset)

    def get_client_id(self):
        return self.client_id

    def train(self, parameters_dict):
        net = to_device(FederatedNet(), device)
        net.apply_parameters(parameters_dict)
        train_history = net.fit(self.dataset, epochs_per_client, learning_rate, batch_size)
        print('{}: Loss = {}, Accuracy = {}'.format(self.client_id, round(train_history[-1][0], 4), round(train_history[-1][1], 4)))
        return net.get_parameters()

# Initialize datasets and clients
examples_per_client = total_train_size // num_clients
client_datasets = random_split(train_dataset, [min(i + examples_per_client,
           total_train_size) - i for i in range(0, total_train_size, examples_per_client)])
clients = [Client('client_' + str(i), client_datasets[i]) for i in range(num_clients)]

# Initialize global network
device = get_device()
global_net = to_device(FederatedNet(), device)


# Training loop for federated learning
history = []
for i in range(rounds):
    print('Start Round {} ...'.format(i + 1))
    curr_parameters = global_net.get_parameters()
    new_parameters = dict([(layer_name, {'weight': 0, 'bias': 0}) for layer_name in curr_parameters])
    for client in clients:
        client_parameters = client.train(curr_parameters)
        fraction = client.get_dataset_size() / total_train_size
        for layer_name in client_parameters:
            new_parameters[layer_name]['weight'] += fraction * client_parameters[layer_name]['weight']
            new_parameters[layer_name]['bias'] += fraction * client_parameters[layer_name]['bias']
    global_net.apply_parameters(new_parameters)

    train_loss, train_acc = global_net.evaluate(train_dataset)
    dev_loss, dev_acc = global_net.evaluate(dev_dataset)
    print('After round {}, train_loss = {}, dev_loss = {}, dev_acc = {}\n'.format(i + 1, round(train_loss, 4),
            round(dev_loss, 4), round(dev_acc, 4)))
    history.append((train_loss, dev_loss))

plt.plot([i + 1 for i in range(len(history))], [history[i][0] for i in range(len(history))], color='r', label='train loss')
plt.plot([i + 1 for i in range(len(history))], [history[i][1] for i in range(len(history))], color='b', label='dev loss')
plt.legend()
plt.title('Training history')
plt.show()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [07:28<00:00, 380331.08it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Start Round 1 ...
# client_0: Loss = 2.2529, Accuracy = 0.1915
# client_1: Loss = 2.2527, Accuracy = 0.1895
# client_2: Loss = 2.2509, Accuracy = 0.1988
# client_3: Loss = 2.2474, Accuracy = 0.18
# client_4: Loss = 2.2472, Accuracy = 0.1886
# client_5: Loss = 2.2498, Accuracy = 0.1607
# client_6: Loss = 2.2428, Accuracy = 0.1741
# client_7: Loss = 2.2527, Accuracy = 0.1905
# After round 1, train_loss = 2.2193, dev_loss = 2.2203, dev_acc = 0.2293
#
# Start Round 2 ...
# client_0: Loss = 2.088, Accuracy = 0.2458
# client_1: Loss = 2.0826, Accuracy = 0.2443
# client_2: Loss = 2.0885, Accuracy = 0.2483
# client_3: Loss = 2.0931, Accuracy = 0.2415
# client_4: Loss = 2.0756, Accuracy = 0.2568
# client_5: Loss = 2.0754, Accuracy = 0.2519
# client_6: Loss = 2.0837, Accuracy = 0.2497
# client_7: Loss = 2.0925, Accuracy = 0.2452
# After round 2, train_loss = 2.027, dev_loss = 2.0265, dev_acc = 0.2762
#
# Start Round 3 ...
# client_0: Loss = 1.971, Accuracy = 0.2979
# client_1: Loss = 1.9861, Accuracy = 0.2868
# client_2: Loss = 1.968, Accuracy = 0.3009
# client_3: Loss = 1.9684, Accuracy = 0.297
# client_4: Loss = 1.9813, Accuracy = 0.2896
# client_5: Loss = 1.9859, Accuracy = 0.2917
# client_6: Loss = 1.9866, Accuracy = 0.2871
# client_7: Loss = 1.9808, Accuracy = 0.29
# After round 3, train_loss = 1.9346, dev_loss = 1.941, dev_acc = 0.3086
#
# Start Round 4 ...
# client_0: Loss = 1.9166, Accuracy = 0.3202
# client_1: Loss = 1.9066, Accuracy = 0.3187
# client_2: Loss = 1.9018, Accuracy = 0.3327
# client_3: Loss = 1.9184, Accuracy = 0.3173
# client_4: Loss = 1.9003, Accuracy = 0.3288
# client_5: Loss = 1.9015, Accuracy = 0.3247
# client_6: Loss = 1.9079, Accuracy = 0.3113
# client_7: Loss = 1.9057, Accuracy = 0.3241
# After round 4, train_loss = 1.8787, dev_loss = 1.8854, dev_acc = 0.3338
#
# Start Round 5 ...
# client_0: Loss = 1.847, Accuracy = 0.3479
# client_1: Loss = 1.8476, Accuracy = 0.3502
# client_2: Loss = 1.8386, Accuracy = 0.3545
# client_3: Loss = 1.8456, Accuracy = 0.3512
# client_4: Loss = 1.8317, Accuracy = 0.3522
# client_5: Loss = 1.8473, Accuracy = 0.3411
# client_6: Loss = 1.8345, Accuracy = 0.3411
# client_7: Loss = 1.8426, Accuracy = 0.343
# After round 5, train_loss = 1.8036, dev_loss = 1.8184, dev_acc = 0.3574
#
# Start Round 6 ...
# client_0: Loss = 1.7905, Accuracy = 0.3638
# client_1: Loss = 1.7801, Accuracy = 0.3731
# client_2: Loss = 1.7856, Accuracy = 0.3731
# client_3: Loss = 1.7711, Accuracy = 0.3821
# client_4: Loss = 1.7883, Accuracy = 0.3617
# client_5: Loss = 1.8027, Accuracy = 0.3681
# client_6: Loss = 1.7773, Accuracy = 0.3743
# client_7: Loss = 1.7898, Accuracy = 0.3669
# After round 6, train_loss = 1.7399, dev_loss = 1.7564, dev_acc = 0.3883
#
# Start Round 7 ...
# client_0: Loss = 1.7232, Accuracy = 0.3873
# client_1: Loss = 1.7413, Accuracy = 0.3973
# client_2: Loss = 1.7306, Accuracy = 0.3908
# client_3: Loss = 1.7367, Accuracy = 0.3922
# client_4: Loss = 1.7362, Accuracy = 0.39
# client_5: Loss = 1.7458, Accuracy = 0.3909
# client_6: Loss = 1.7069, Accuracy = 0.3885
# client_7: Loss = 1.7351, Accuracy = 0.392
# After round 7, train_loss = 1.6758, dev_loss = 1.6924, dev_acc = 0.4097
#
# Start Round 8 ...
# client_0: Loss = 1.6684, Accuracy = 0.416
# client_1: Loss = 1.691, Accuracy = 0.411
# client_2: Loss = 1.6635, Accuracy = 0.4145
# client_3: Loss = 1.657, Accuracy = 0.4172
# client_4: Loss = 1.6588, Accuracy = 0.4125
# client_5: Loss = 1.6525, Accuracy = 0.4162
# client_6: Loss = 1.6649, Accuracy = 0.406
# client_7: Loss = 1.6703, Accuracy = 0.4045
# After round 8, train_loss = 1.6227, dev_loss = 1.642, dev_acc = 0.4239
#
# Start Round 9 ...
# client_0: Loss = 1.6118, Accuracy = 0.4275
# client_1: Loss = 1.6099, Accuracy = 0.4283
# client_2: Loss = 1.6335, Accuracy = 0.4239
# client_3: Loss = 1.6044, Accuracy = 0.4338
# client_4: Loss = 1.6208, Accuracy = 0.4284
# client_5: Loss = 1.6084, Accuracy = 0.4297
# client_6: Loss = 1.6193, Accuracy = 0.4198
# client_7: Loss = 1.6179, Accuracy = 0.4343
# After round 9, train_loss = 1.5654, dev_loss = 1.5842, dev_acc = 0.444
#
# Start Round 10 ...
# client_0: Loss = 1.5493, Accuracy = 0.4495
# client_1: Loss = 1.5731, Accuracy = 0.4449
# client_2: Loss = 1.5744, Accuracy = 0.4502
# client_3: Loss = 1.5624, Accuracy = 0.4501
# client_4: Loss = 1.5656, Accuracy = 0.4462
# client_5: Loss = 1.5829, Accuracy = 0.4358
# client_6: Loss = 1.5689, Accuracy = 0.4367
# client_7: Loss = 1.5995, Accuracy = 0.4334
# After round 10, train_loss = 1.5371, dev_loss = 1.5565, dev_acc = 0.4543
#
# Start Round 11 ...
# client_0: Loss = 1.5327, Accuracy = 0.4496
# client_1: Loss = 1.5443, Accuracy = 0.4528
# client_2: Loss = 1.5404, Accuracy = 0.4559
# client_3: Loss = 1.525, Accuracy = 0.4602
# client_4: Loss = 1.5446, Accuracy = 0.4504
# client_5: Loss = 1.5403, Accuracy = 0.4554
# client_6: Loss = 1.5232, Accuracy = 0.4551
# client_7: Loss = 1.5579, Accuracy = 0.4564
# After round 11, train_loss = 1.5044, dev_loss = 1.5241, dev_acc = 0.4582
#
# Start Round 12 ...
# client_0: Loss = 1.511, Accuracy = 0.4648
# client_1: Loss = 1.5026, Accuracy = 0.4737
# client_2: Loss = 1.4905, Accuracy = 0.4787
# client_3: Loss = 1.4922, Accuracy = 0.465
# client_4: Loss = 1.499, Accuracy = 0.4704
# client_5: Loss = 1.5103, Accuracy = 0.4639
# client_6: Loss = 1.5177, Accuracy = 0.4611
# client_7: Loss = 1.5179, Accuracy = 0.4668
# After round 12, train_loss = 1.4733, dev_loss = 1.4952, dev_acc = 0.4755
#
# Start Round 13 ...
# client_0: Loss = 1.4757, Accuracy = 0.4761
# client_1: Loss = 1.494, Accuracy = 0.4741
# client_2: Loss = 1.4951, Accuracy = 0.4728
# client_3: Loss = 1.4649, Accuracy = 0.482
# client_4: Loss = 1.4893, Accuracy = 0.4739
# client_5: Loss = 1.491, Accuracy = 0.4675
# client_6: Loss = 1.4884, Accuracy = 0.4697
# client_7: Loss = 1.5064, Accuracy = 0.4669
# After round 13, train_loss = 1.4605, dev_loss = 1.4805, dev_acc = 0.4815
#
# Start Round 14 ...
# client_0: Loss = 1.4631, Accuracy = 0.4902
# client_1: Loss = 1.4753, Accuracy = 0.4816
# client_2: Loss = 1.4701, Accuracy = 0.4821
# client_3: Loss = 1.4526, Accuracy = 0.4771
# client_4: Loss = 1.4726, Accuracy = 0.4817
# client_5: Loss = 1.4609, Accuracy = 0.4822
# client_6: Loss = 1.4863, Accuracy = 0.4655
# client_7: Loss = 1.483, Accuracy = 0.4774
# After round 14, train_loss = 1.4424, dev_loss = 1.4647, dev_acc = 0.4862
#
# Start Round 15 ...
# client_0: Loss = 1.4344, Accuracy = 0.4965
# client_1: Loss = 1.4551, Accuracy = 0.4886
# client_2: Loss = 1.4542, Accuracy = 0.486
# client_3: Loss = 1.4422, Accuracy = 0.484
# client_4: Loss = 1.4319, Accuracy = 0.4903
# client_5: Loss = 1.4557, Accuracy = 0.4853
# client_6: Loss = 1.4549, Accuracy = 0.4738
# client_7: Loss = 1.4593, Accuracy = 0.4782
# After round 15, train_loss = 1.4285, dev_loss = 1.4529, dev_acc = 0.4959
#
# Start Round 16 ...
# client_0: Loss = 1.4269, Accuracy = 0.5008
# client_1: Loss = 1.4417, Accuracy = 0.4932
# client_2: Loss = 1.4244, Accuracy = 0.4992
# client_3: Loss = 1.4239, Accuracy = 0.4962
# client_4: Loss = 1.4225, Accuracy = 0.4949
# client_5: Loss = 1.4305, Accuracy = 0.502
# client_6: Loss = 1.4332, Accuracy = 0.4856
# client_7: Loss = 1.4426, Accuracy = 0.4917
# After round 16, train_loss = 1.4144, dev_loss = 1.4395, dev_acc = 0.4947
#
# Start Round 17 ...
# client_0: Loss = 1.3977, Accuracy = 0.5138
# client_1: Loss = 1.4276, Accuracy = 0.4986
# client_2: Loss = 1.4138, Accuracy = 0.5027
# client_3: Loss = 1.3993, Accuracy = 0.4987
# client_4: Loss = 1.4048, Accuracy = 0.5065
# client_5: Loss = 1.4211, Accuracy = 0.4974
# client_6: Loss = 1.4307, Accuracy = 0.4917
# client_7: Loss = 1.4327, Accuracy = 0.4973
# After round 17, train_loss = 1.4078, dev_loss = 1.432, dev_acc = 0.5009
#
# Start Round 18 ...
# client_0: Loss = 1.3967, Accuracy = 0.5045
# client_1: Loss = 1.4159, Accuracy = 0.5047
# client_2: Loss = 1.3951, Accuracy = 0.5086
# client_3: Loss = 1.3916, Accuracy = 0.5016
# client_4: Loss = 1.4141, Accuracy = 0.5009
# client_5: Loss = 1.4092, Accuracy = 0.5075
# client_6: Loss = 1.4114, Accuracy = 0.5012
# client_7: Loss = 1.4119, Accuracy = 0.4948
# After round 18, train_loss = 1.3898, dev_loss = 1.4214, dev_acc = 0.5043
#
# Start Round 19 ...
# client_0: Loss = 1.381, Accuracy = 0.5217
# client_1: Loss = 1.405, Accuracy = 0.505
# client_2: Loss = 1.3881, Accuracy = 0.5089
# client_3: Loss = 1.3864, Accuracy = 0.5114
# client_4: Loss = 1.3834, Accuracy = 0.5208
# client_5: Loss = 1.3948, Accuracy = 0.5131
# client_6: Loss = 1.4003, Accuracy = 0.5082
# client_7: Loss = 1.397, Accuracy = 0.5064
# After round 19, train_loss = 1.3727, dev_loss = 1.4034, dev_acc = 0.5095
#
# Start Round 20 ...
# client_0: Loss = 1.3642, Accuracy = 0.5182
# client_1: Loss = 1.3902, Accuracy = 0.5101
# client_2: Loss = 1.3744, Accuracy = 0.5202
# client_3: Loss = 1.3671, Accuracy = 0.5193
# client_4: Loss = 1.3809, Accuracy = 0.5145
# client_5: Loss = 1.3778, Accuracy = 0.5125
# client_6: Loss = 1.3817, Accuracy = 0.5138
# client_7: Loss = 1.3921, Accuracy = 0.5136
# After round 20, train_loss = 1.3654, dev_loss = 1.3941, dev_acc = 0.5186
#
# Start Round 21 ...
# client_0: Loss = 1.3525, Accuracy = 0.5187
# client_1: Loss = 1.3819, Accuracy = 0.5142
# client_2: Loss = 1.3556, Accuracy = 0.5276
# client_3: Loss = 1.3478, Accuracy = 0.5188
# client_4: Loss = 1.3578, Accuracy = 0.5268
# client_5: Loss = 1.3562, Accuracy = 0.5245
# client_6: Loss = 1.3686, Accuracy = 0.5255
# client_7: Loss = 1.3704, Accuracy = 0.5195
# After round 21, train_loss = 1.3494, dev_loss = 1.382, dev_acc = 0.518
#
# Start Round 22 ...
# client_0: Loss = 1.343, Accuracy = 0.5365
# client_1: Loss = 1.3605, Accuracy = 0.5193
# client_2: Loss = 1.3529, Accuracy = 0.5253
# client_3: Loss = 1.3402, Accuracy = 0.5184
# client_4: Loss = 1.3427, Accuracy = 0.5235
# client_5: Loss = 1.3515, Accuracy = 0.5207
# client_6: Loss = 1.3514, Accuracy = 0.528
# client_7: Loss = 1.3548, Accuracy = 0.5251
# After round 22, train_loss = 1.3359, dev_loss = 1.3689, dev_acc = 0.5218
#
# Start Round 23 ...
# client_0: Loss = 1.3386, Accuracy = 0.5303
# client_1: Loss = 1.353, Accuracy = 0.5273
# client_2: Loss = 1.344, Accuracy = 0.5223
# client_3: Loss = 1.3222, Accuracy = 0.5287
# client_4: Loss = 1.3368, Accuracy = 0.5311
# client_5: Loss = 1.3435, Accuracy = 0.5322
# client_6: Loss = 1.357, Accuracy = 0.5172
# client_7: Loss = 1.3421, Accuracy = 0.528
# After round 23, train_loss = 1.3279, dev_loss = 1.364, dev_acc = 0.5238
#
# Start Round 24 ...
# client_0: Loss = 1.3141, Accuracy = 0.5443
# client_1: Loss = 1.3468, Accuracy = 0.5269
# client_2: Loss = 1.3258, Accuracy = 0.5347
# client_3: Loss = 1.313, Accuracy = 0.5357
# client_4: Loss = 1.326, Accuracy = 0.5287
# client_5: Loss = 1.326, Accuracy = 0.5384
# client_6: Loss = 1.3463, Accuracy = 0.5247
# client_7: Loss = 1.3312, Accuracy = 0.5339
# After round 24, train_loss = 1.3137, dev_loss = 1.3495, dev_acc = 0.5316
#
# Start Round 25 ...
# client_0: Loss = 1.3051, Accuracy = 0.5482
# client_1: Loss = 1.3335, Accuracy = 0.5348
# client_2: Loss = 1.3153, Accuracy = 0.54
# client_3: Loss = 1.3131, Accuracy = 0.5362
# client_4: Loss = 1.3137, Accuracy = 0.5405
# client_5: Loss = 1.3076, Accuracy = 0.5436
# client_6: Loss = 1.3223, Accuracy = 0.5309
