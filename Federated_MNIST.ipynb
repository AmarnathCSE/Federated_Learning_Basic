# %%
import torch
from torchvision.datasets import MNIST
from torch.utils.data import random_split, DataLoader
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [5, 5]

# %%
train_dataset = MNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())
test_dataset = MNIST(root='./data', train=False, download=True, transform=transforms.ToTensor())

train_dataset, dev_dataset = random_split(train_dataset, [int(len(train_dataset) * 0.83), int(len(train_dataset) * 0.17)])

# %%
total_train_size = len(train_dataset)
total_test_size = len(test_dataset)
total_dev_size = len(dev_dataset)

classes = 10
input_dim = 784

num_clients = 8
rounds = 20
batch_size = 128
epochs_per_client = 3
learning_rate = 2e-2

# %%
total_train_size, total_dev_size, total_test_size
# Out:
# (49800, 10200, 10000)

# %%
def get_device():
    return torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader(DataLoader):
        def __init__(self, dl, device):
            self.dl = dl
            self.device = device

        def __iter__(self):
            for batch in self.dl:
                yield to_device(batch, self.device)

        def __len__(self):
          return len(self.dl)

device = get_device()

# %%
class FederatedNet(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(1, 20, 7)
        self.conv2 = torch.nn.Conv2d(20, 40, 7)
        self.maxpool = torch.nn.MaxPool2d(2, 2)
        self.flatten = torch.nn.Flatten()
        self.linear = torch.nn.Linear(2560, 10)
        self.non_linearity = torch.nn.functional.relu
        self.track_layers = {'conv1': self.conv1, 'conv2': self.conv2, 'linear': self.linear}
    def forward(self, x_batch):
        out = self.conv1(x_batch)
        out = self.non_linearity(out)
        out = self.conv2(out)
        out = self.non_linearity(out)
        out = self.maxpool(out)
        out = self.flatten(out)
        out = self.linear(out)
        return out

    def get_track_layers(self):
        return self.track_layers

    def apply_parameters(self, parameters_dict):
        with torch.no_grad():
            for layer_name in parameters_dict:
                self.track_layers[layer_name].weight.data *= 0
                self.track_layers[layer_name].bias.data *= 0
                self.track_layers[layer_name].weight.data += parameters_dict[layer_name]['weight']
                self.track_layers[layer_name].bias.data += parameters_dict[layer_name]['bias']

    def get_parameters(self):
        parameters_dict = dict()
        for layer_name in self.track_layers:
            parameters_dict[layer_name] = {
                'weight': self.track_layers[layer_name].weight.data,
                'bias': self.track_layers[layer_name].bias.data
            }
        return parameters_dict

    def batch_accuracy(self, outputs, labels):
        with torch.no_grad():
            _, predictions = torch.max(outputs, dim=1)
            return torch.tensor(torch.sum(predictions == labels).item() / len(predictions))

    def _process_batch(self, batch):
        images, labels = batch
        outputs = self(images)
        loss = torch.nn.functional.cross_entropy(outputs, labels)
        accuracy = self.batch_accuracy(outputs, labels)
        return (loss, accuracy)

    def fit(self, dataset, epochs, lr, batch_size=128, opt=torch.optim.SGD):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size, shuffle=True), device)
        optimizer = opt(self.parameters(), lr)
        history = []
        for epoch in range(epochs):
            losses = []
            accs = []
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                loss.backward()
                optimizer.step()
                optimizer.zero_grad()
                loss.detach()
                losses.append(loss)
                accs.append(acc)
            avg_loss = torch.stack(losses).mean().item()
            avg_acc = torch.stack(accs).mean().item()
            history.append((avg_loss, avg_acc))
        return history

    def evaluate(self, dataset, batch_size=128):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size), device)
        losses = []
        accs = []
        with torch.no_grad():
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                losses.append(loss)
                accs.append(acc)
        avg_loss = torch.stack(losses).mean().item()
        avg_acc = torch.stack(accs).mean().item()
        return (avg_loss, avg_acc)

# %%
class Client:
    def __init__(self, client_id, dataset):
        self.client_id = client_id
        self.dataset = dataset

    def get_dataset_size(self):
        return len(self.dataset)

    def get_client_id(self):
        return self.client_id

    def train(self, parameters_dict):
        net = to_device(FederatedNet(), device)
        net.apply_parameters(parameters_dict)
        train_history = net.fit(self.dataset, epochs_per_client, learning_rate, batch_size)
        print('{}: Loss = {}, Accuracy = {}'.format(self.client_id, round(train_history[-1][0], 4), round(train_history[-1][1], 4)))
        return net.get_parameters()

# %%
examples_per_client = total_train_size // num_clients
client_datasets = random_split(train_dataset, [min(i + examples_per_client,
           total_train_size) - i for i in range(0, total_train_size, examples_per_client)])
clients = [Client('client_' + str(i), client_datasets[i]) for i in range(num_clients)]

# %%
global_net = to_device(FederatedNet(), device)
history = []
for i in range(rounds):
    print('Start Round {} ...'.format(i + 1))
    curr_parameters = global_net.get_parameters()
    new_parameters = dict([(layer_name, {'weight': 0, 'bias': 0}) for layer_name in curr_parameters])
    for client in clients:
        client_parameters = client.train(curr_parameters)
        fraction = client.get_dataset_size() / total_train_size
        for layer_name in client_parameters:
            new_parameters[layer_name]['weight'] += fraction * client_parameters[layer_name]['weight']
            new_parameters[layer_name]['bias'] += fraction * client_parameters[layer_name]['bias']
    global_net.apply_parameters(new_parameters)

    train_loss, train_acc = global_net.evaluate(train_dataset)
    dev_loss, dev_acc = global_net.evaluate(dev_dataset)
    print('After round {}, train_loss = {}, dev_loss = {}, dev_acc = {}\n'.format(i + 1, round(train_loss, 4),
            round(dev_loss, 4), round(dev_acc, 4)))
    history.append((train_loss, dev_loss))
# Out:
# Start Round 1 ...
# client_0: Loss = 0.4892, Accuracy = 0.8456
# client_1: Loss = 0.467, Accuracy = 0.8538
# client_2: Loss = 0.4798, Accuracy = 0.8511
# client_3: Loss = 0.4776, Accuracy = 0.8531
# client_4: Loss = 0.4897, Accuracy = 0.8483
# client_5: Loss = 0.4979, Accuracy = 0.851
# client_6: Loss = 0.4779, Accuracy = 0.8572
# client_7: Loss = 0.4961, Accuracy = 0.8517
# After round 1, train_loss = 0.3975, dev_loss = 0.3919, dev_acc = 0.8862
#
# Start Round 2 ...
# client_0: Loss = 0.3076, Accuracy = 0.9079
# client_1: Loss = 0.2948, Accuracy = 0.9102
# client_2: Loss = 0.3035, Accuracy = 0.9097
# client_3: Loss = 0.3091, Accuracy = 0.908
# client_4: Loss = 0.3125, Accuracy = 0.9047
# client_5: Loss = 0.3299, Accuracy = 0.9056
# client_6: Loss = 0.3087, Accuracy = 0.912
# client_7: Loss = 0.3327, Accuracy = 0.9042
# After round 2, train_loss = 0.2828, dev_loss = 0.2759, dev_acc = 0.9216
#
# Start Round 3 ...
# client_0: Loss = 0.221, Accuracy = 0.9333
# client_1: Loss = 0.2166, Accuracy = 0.936
# client_2: Loss = 0.2202, Accuracy = 0.9338
# client_3: Loss = 0.2255, Accuracy = 0.9375
# client_4: Loss = 0.2292, Accuracy = 0.9321
# client_5: Loss = 0.2462, Accuracy = 0.9304
# client_6: Loss = 0.2217, Accuracy = 0.9369
# client_7: Loss = 0.243, Accuracy = 0.9306
# After round 3, train_loss = 0.2127, dev_loss = 0.2066, dev_acc = 0.9418
#
# Start Round 4 ...
# client_0: Loss = 0.1671, Accuracy = 0.9498
# client_1: Loss = 0.1678, Accuracy = 0.9504
# client_2: Loss = 0.1691, Accuracy = 0.953
# client_3: Loss = 0.1764, Accuracy = 0.9531
# client_4: Loss = 0.1842, Accuracy = 0.9444
# client_5: Loss = 0.1945, Accuracy = 0.9454
# client_6: Loss = 0.1719, Accuracy = 0.9528
# client_7: Loss = 0.1916, Accuracy = 0.9441
# After round 4, train_loss = 0.1692, dev_loss = 0.1654, dev_acc = 0.9515
#
# Start Round 5 ...
# client_0: Loss = 0.1358, Accuracy = 0.9625
# client_1: Loss = 0.1364, Accuracy = 0.961
# client_2: Loss = 0.1381, Accuracy = 0.9602
# client_3: Loss = 0.1471, Accuracy = 0.9617
# client_4: Loss = 0.1487, Accuracy = 0.9557
# client_5: Loss = 0.1607, Accuracy = 0.9537
# client_6: Loss = 0.1452, Accuracy = 0.9604
# client_7: Loss = 0.157, Accuracy = 0.9552
# After round 5, train_loss = 0.1402, dev_loss = 0.1379, dev_acc = 0.9578
#
# Start Round 6 ...
# client_0: Loss = 0.115, Accuracy = 0.9667
# client_1: Loss = 0.1155, Accuracy = 0.9661
# client_2: Loss = 0.1201, Accuracy = 0.9661
# client_3: Loss = 0.1272, Accuracy = 0.9661
# client_4: Loss = 0.1283, Accuracy = 0.962
# client_5: Loss = 0.1399, Accuracy = 0.9605
# client_6: Loss = 0.1212, Accuracy = 0.9678
# client_7: Loss = 0.1357, Accuracy = 0.9599
# After round 6, train_loss = 0.1225, dev_loss = 0.1215, dev_acc = 0.963
#
# Start Round 7 ...
# client_0: Loss = 0.1015, Accuracy = 0.9711
# client_1: Loss = 0.1015, Accuracy = 0.9689
# client_2: Loss = 0.1068, Accuracy = 0.9686
# client_3: Loss = 0.1125, Accuracy = 0.97
# client_4: Loss = 0.1117, Accuracy = 0.9682
# client_5: Loss = 0.1258, Accuracy = 0.9655
# client_6: Loss = 0.1091, Accuracy = 0.9685
# client_7: Loss = 0.1207, Accuracy = 0.9642
# After round 7, train_loss = 0.1101, dev_loss = 0.1091, dev_acc = 0.9663
#
# Start Round 8 ...
# client_0: Loss = 0.0918, Accuracy = 0.9721
# client_1: Loss = 0.0946, Accuracy = 0.972
# client_2: Loss = 0.096, Accuracy = 0.971
# client_3: Loss = 0.1019, Accuracy = 0.9725
# client_4: Loss = 0.1005, Accuracy = 0.9706
# client_5: Loss = 0.114, Accuracy = 0.9668
# client_6: Loss = 0.0979, Accuracy = 0.9726
# client_7: Loss = 0.11, Accuracy = 0.9677
# After round 8, train_loss = 0.0991, dev_loss = 0.0991, dev_acc = 0.9694
#
# Start Round 9 ...
# client_0: Loss = 0.0827, Accuracy = 0.9766
# client_1: Loss = 0.0831, Accuracy = 0.9754
# client_2: Loss = 0.0873, Accuracy = 0.9734
# client_3: Loss = 0.0924, Accuracy = 0.9756
# client_4: Loss = 0.0926, Accuracy = 0.9737
# client_5: Loss = 0.1029, Accuracy = 0.9695
# client_6: Loss = 0.0868, Accuracy = 0.9748
# client_7: Loss = 0.0988, Accuracy = 0.9706
# After round 9, train_loss = 0.0905, dev_loss = 0.0911, dev_acc = 0.9727
#
# Start Round 10 ...
# client_0: Loss = 0.0775, Accuracy = 0.9785
# client_1: Loss = 0.0769, Accuracy = 0.9776
# client_2: Loss = 0.0808, Accuracy = 0.9752
# client_3: Loss = 0.0871, Accuracy = 0.9758
# client_4: Loss = 0.0849, Accuracy = 0.9749
# client_5: Loss = 0.0968, Accuracy = 0.9735
# client_6: Loss = 0.0826, Accuracy = 0.976
# client_7: Loss = 0.0932, Accuracy = 0.9726
# After round 10, train_loss = 0.0838, dev_loss = 0.086, dev_acc = 0.9743
#
# Start Round 11 ...
# client_0: Loss = 0.0692, Accuracy = 0.9792
# client_1: Loss = 0.0718, Accuracy = 0.9781
# client_2: Loss = 0.0757, Accuracy = 0.9774
# client_3: Loss = 0.0815, Accuracy = 0.9772
# client_4: Loss = 0.0801, Accuracy = 0.9774
# client_5: Loss = 0.0899, Accuracy = 0.9744
# client_6: Loss = 0.0767, Accuracy = 0.978
# client_7: Loss = 0.0867, Accuracy = 0.9744
# After round 11, train_loss = 0.0792, dev_loss = 0.0828, dev_acc = 0.9753
#
# Start Round 12 ...
# client_0: Loss = 0.0653, Accuracy = 0.9806
# client_1: Loss = 0.0659, Accuracy = 0.981
# client_2: Loss = 0.0696, Accuracy = 0.9801
# client_3: Loss = 0.0773, Accuracy = 0.9774
# client_4: Loss = 0.0755, Accuracy = 0.977
# client_5: Loss = 0.0857, Accuracy = 0.9744
# client_6: Loss = 0.0729, Accuracy = 0.9811
# client_7: Loss = 0.0824, Accuracy = 0.9747
# After round 12, train_loss = 0.0744, dev_loss = 0.0792, dev_acc = 0.9773
#
# Start Round 13 ...
# client_0: Loss = 0.062, Accuracy = 0.9815
# client_1: Loss = 0.0627, Accuracy = 0.9815
# client_2: Loss = 0.0647, Accuracy = 0.9803
# client_3: Loss = 0.0722, Accuracy = 0.9805
# client_4: Loss = 0.0705, Accuracy = 0.9793
# client_5: Loss = 0.0789, Accuracy = 0.9777
# client_6: Loss = 0.0686, Accuracy = 0.98
# client_7: Loss = 0.0751, Accuracy = 0.9789
# After round 13, train_loss = 0.0707, dev_loss = 0.076, dev_acc = 0.9778
#
# Start Round 14 ...
# client_0: Loss = 0.0591, Accuracy = 0.9817
# client_1: Loss = 0.0598, Accuracy = 0.9815
# client_2: Loss = 0.0629, Accuracy = 0.9798
# client_3: Loss = 0.069, Accuracy = 0.9777
# client_4: Loss = 0.0675, Accuracy = 0.9798
# client_5: Loss = 0.0755, Accuracy = 0.9784
# client_6: Loss = 0.0666, Accuracy = 0.9811
# client_7: Loss = 0.0707, Accuracy = 0.9791
# After round 14, train_loss = 0.067, dev_loss = 0.0732, dev_acc = 0.979
#
# Start Round 15 ...
# client_0: Loss = 0.0547, Accuracy = 0.9828
# client_1: Loss = 0.0562, Accuracy = 0.9833
# client_2: Loss = 0.0587, Accuracy = 0.9818
# client_3: Loss = 0.0667, Accuracy = 0.9795
# client_4: Loss = 0.0639, Accuracy = 0.9809
# client_5: Loss = 0.0717, Accuracy = 0.9804
# client_6: Loss = 0.0626, Accuracy = 0.9824
# client_7: Loss = 0.0672, Accuracy = 0.9802
# After round 15, train_loss = 0.0639, dev_loss = 0.0712, dev_acc = 0.9796
#
# Start Round 16 ...
# client_0: Loss = 0.0517, Accuracy = 0.9859
# client_1: Loss = 0.0549, Accuracy = 0.9836
# client_2: Loss = 0.0583, Accuracy = 0.9821
# client_3: Loss = 0.0615, Accuracy = 0.9818
# client_4: Loss = 0.0621, Accuracy = 0.9821
# client_5: Loss = 0.0675, Accuracy = 0.9798
# client_6: Loss = 0.061, Accuracy = 0.982
# client_7: Loss = 0.065, Accuracy = 0.982
# After round 16, train_loss = 0.0625, dev_loss = 0.0705, dev_acc = 0.9793
#
# Start Round 17 ...
# client_0: Loss = 0.0485, Accuracy = 0.9855
# client_1: Loss = 0.0528, Accuracy = 0.9842
# client_2: Loss = 0.0546, Accuracy = 0.9828
# client_3: Loss = 0.0592, Accuracy = 0.9842
# client_4: Loss = 0.0584, Accuracy = 0.9828
# client_5: Loss = 0.0655, Accuracy = 0.9809
# client_6: Loss = 0.0584, Accuracy = 0.9845
# client_7: Loss = 0.0623, Accuracy = 0.9826
# After round 17, train_loss = 0.0596, dev_loss = 0.0685, dev_acc = 0.9805
#
# Start Round 18 ...
# client_0: Loss = 0.0464, Accuracy = 0.9877
# client_1: Loss = 0.0502, Accuracy = 0.985
# client_2: Loss = 0.053, Accuracy = 0.9843
# client_3: Loss = 0.0572, Accuracy = 0.9831
# client_4: Loss = 0.0555, Accuracy = 0.9843
# client_5: Loss = 0.0619, Accuracy = 0.9819
# client_6: Loss = 0.0559, Accuracy = 0.9843
# client_7: Loss = 0.0587, Accuracy = 0.9821
# After round 18, train_loss = 0.058, dev_loss = 0.0687, dev_acc = 0.981
#
# Start Round 19 ...
# client_0: Loss = 0.0458, Accuracy = 0.9864
# client_1: Loss = 0.0483, Accuracy = 0.9847
# client_2: Loss = 0.0481, Accuracy = 0.9867
# client_3: Loss = 0.0545, Accuracy = 0.9842
# client_4: Loss = 0.0549, Accuracy = 0.9837
# client_5: Loss = 0.0584, Accuracy = 0.9836
# client_6: Loss = 0.0532, Accuracy = 0.9849
# client_7: Loss = 0.0586, Accuracy = 0.9824
# After round 19, train_loss = 0.0565, dev_loss = 0.0671, dev_acc = 0.9816
#
# Start Round 20 ...
# client_0: Loss = 0.0443, Accuracy = 0.9874
# client_1: Loss = 0.0463, Accuracy = 0.9868
# client_2: Loss = 0.0466, Accuracy = 0.9857
# client_3: Loss = 0.0525, Accuracy = 0.9847
# client_4: Loss = 0.052, Accuracy = 0.9851
# client_5: Loss = 0.058, Accuracy = 0.9825
# client_6: Loss = 0.0525, Accuracy = 0.9852
# client_7: Loss = 0.0556, Accuracy = 0.9836
# After round 20, train_loss = 0.0533, dev_loss = 0.0642, dev_acc = 0.9815

# %%
plt.plot([i + 1 for i in range(len(history))], [history[i][0] for i in range(len(history))], color='r', label='train loss')
plt.plot([i + 1 for i in range(len(history))], [history[i][1] for i in range(len(history))], color='b', label='dev loss')
plt.legend()
plt.title('Training history')
plt.show()
