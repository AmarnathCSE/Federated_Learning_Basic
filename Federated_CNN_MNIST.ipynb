# %%
import torch
from torchvision.datasets import MNIST
from torch.utils.data import random_split, DataLoader
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [5, 5]

# %%
train_dataset = MNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())
test_dataset = MNIST(root='./data', train=False, download=True, transform=transforms.ToTensor())

train_dataset, dev_dataset = random_split(train_dataset, [int(len(train_dataset) * 0.83), int(len(train_dataset) * 0.17)])

# %%
total_train_size = len(train_dataset)
total_test_size = len(test_dataset)
total_dev_size = len(dev_dataset)

classes = 10
input_dim = 784

num_clients = 8
rounds = 30
batch_size = 128
epochs_per_client = 3
learning_rate = 2e-2

# %%
total_train_size, total_dev_size, total_test_size
# Out:
# (49800, 10200, 10000)

# %%
def get_device():
    return torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader(DataLoader):
        def __init__(self, dl, device):
            self.dl = dl
            self.device = device

        def __iter__(self):
            for batch in self.dl:
                yield to_device(batch, self.device)

        def __len__(self):
          return len(self.dl)

device = get_device()

# %%
class FederatedNet(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(1, 20, 7)
        self.conv2 = torch.nn.Conv2d(20, 40, 7)
        self.maxpool = torch.nn.MaxPool2d(2, 2)
        self.flatten = torch.nn.Flatten()
        self.linear = torch.nn.Linear(2560, 10)
        self.non_linearity = torch.nn.functional.relu
        self.track_layers = {'conv1': self.conv1, 'conv2': self.conv2, 'linear': self.linear}
    def forward(self, x_batch):
        out = self.conv1(x_batch)
        out = self.non_linearity(out)
        out = self.conv2(out)
        out = self.non_linearity(out)
        out = self.maxpool(out)
        out = self.flatten(out)
        out = self.linear(out)
        return out

    def get_track_layers(self):
        return self.track_layers

    def apply_parameters(self, parameters_dict):
        with torch.no_grad():
            for layer_name in parameters_dict:
                self.track_layers[layer_name].weight.data *= 0
                self.track_layers[layer_name].bias.data *= 0
                self.track_layers[layer_name].weight.data += parameters_dict[layer_name]['weight']
                self.track_layers[layer_name].bias.data += parameters_dict[layer_name]['bias']

    def get_parameters(self):
        parameters_dict = dict()
        for layer_name in self.track_layers:
            parameters_dict[layer_name] = {
                'weight': self.track_layers[layer_name].weight.data,
                'bias': self.track_layers[layer_name].bias.data
            }
        return parameters_dict

    def batch_accuracy(self, outputs, labels):
        with torch.no_grad():
            _, predictions = torch.max(outputs, dim=1)
            return torch.tensor(torch.sum(predictions == labels).item() / len(predictions))

    def _process_batch(self, batch):
        images, labels = batch
        outputs = self(images)
        loss = torch.nn.functional.cross_entropy(outputs, labels)
        accuracy = self.batch_accuracy(outputs, labels)
        return (loss, accuracy)

    def fit(self, dataset, epochs, lr, batch_size=128, opt=torch.optim.SGD):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size, shuffle=True), device)
        optimizer = opt(self.parameters(), lr)
        history = []
        for epoch in range(epochs):
            losses = []
            accs = []
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                loss.backward()
                optimizer.step()
                optimizer.zero_grad()
                loss.detach()
                losses.append(loss)
                accs.append(acc)
            avg_loss = torch.stack(losses).mean().item()
            avg_acc = torch.stack(accs).mean().item()
            history.append((avg_loss, avg_acc))
        return history

    def evaluate(self, dataset, batch_size=128):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size), device)
        losses = []
        accs = []
        with torch.no_grad():
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                losses.append(loss)
                accs.append(acc)
        avg_loss = torch.stack(losses).mean().item()
        avg_acc = torch.stack(accs).mean().item()
        return (avg_loss, avg_acc)

# %%
class Client:
    def __init__(self, client_id, dataset):
        self.client_id = client_id
        self.dataset = dataset

    def get_dataset_size(self):
        return len(self.dataset)

    def get_client_id(self):
        return self.client_id

    def train(self, parameters_dict):
        net = to_device(FederatedNet(), device)
        net.apply_parameters(parameters_dict)
        train_history = net.fit(self.dataset, epochs_per_client, learning_rate, batch_size)
        print('{}: Loss = {}, Accuracy = {}'.format(self.client_id, round(train_history[-1][0], 4), round(train_history[-1][1], 4)))
        return net.get_parameters()

# %%
examples_per_client = total_train_size // num_clients
client_datasets = random_split(train_dataset, [min(i + examples_per_client,
           total_train_size) - i for i in range(0, total_train_size, examples_per_client)])
clients = [Client('client_' + str(i), client_datasets[i]) for i in range(num_clients)]

# %%
global_net = to_device(FederatedNet(), device)
history = []
for i in range(rounds):
    print('Start Round {} ...'.format(i + 1))
    curr_parameters = global_net.get_parameters()
    new_parameters = dict([(layer_name, {'weight': 0, 'bias': 0}) for layer_name in curr_parameters])
    for client in clients:
        client_parameters = client.train(curr_parameters)
        fraction = client.get_dataset_size() / total_train_size
        for layer_name in client_parameters:
            new_parameters[layer_name]['weight'] += fraction * client_parameters[layer_name]['weight']
            new_parameters[layer_name]['bias'] += fraction * client_parameters[layer_name]['bias']
    global_net.apply_parameters(new_parameters)

    train_loss, train_acc = global_net.evaluate(train_dataset)
    dev_loss, dev_acc = global_net.evaluate(dev_dataset)
    print('After round {}, train_loss = {}, dev_loss = {}, dev_acc = {}\n'.format(i + 1, round(train_loss, 4),
            round(dev_loss, 4), round(dev_acc, 4)))
    history.append((train_loss, dev_loss))
# Out:
# Start Round 1 ...
# client_0: Loss = 0.4533, Accuracy = 0.8599
# client_1: Loss = 0.4457, Accuracy = 0.8607
# client_2: Loss = 0.4329, Accuracy = 0.8657
# client_3: Loss = 0.4811, Accuracy = 0.8526
# client_4: Loss = 0.4429, Accuracy = 0.8682
# client_5: Loss = 0.4748, Accuracy = 0.8592
# client_6: Loss = 0.4586, Accuracy = 0.8601
# client_7: Loss = 0.4742, Accuracy = 0.8573
# After round 1, train_loss = 0.3863, dev_loss = 0.3974, dev_acc = 0.8842
#
# Start Round 2 ...
# client_0: Loss = 0.2993, Accuracy = 0.9126
# client_1: Loss = 0.2862, Accuracy = 0.9173
# client_2: Loss = 0.2899, Accuracy = 0.9136
# client_3: Loss = 0.3024, Accuracy = 0.9141
# client_4: Loss = 0.2832, Accuracy = 0.9163
# client_5: Loss = 0.3137, Accuracy = 0.9082
# client_6: Loss = 0.3049, Accuracy = 0.9137
# client_7: Loss = 0.3058, Accuracy = 0.9119
# After round 2, train_loss = 0.2727, dev_loss = 0.2839, dev_acc = 0.9184
#
# Start Round 3 ...
# client_0: Loss = 0.2183, Accuracy = 0.9355
# client_1: Loss = 0.2093, Accuracy = 0.9412
# client_2: Loss = 0.2124, Accuracy = 0.9387
# client_3: Loss = 0.2224, Accuracy = 0.9362
# client_4: Loss = 0.2082, Accuracy = 0.9417
# client_5: Loss = 0.2346, Accuracy = 0.9309
# client_6: Loss = 0.2261, Accuracy = 0.9346
# client_7: Loss = 0.2273, Accuracy = 0.9361
# After round 3, train_loss = 0.2068, dev_loss = 0.2162, dev_acc = 0.9374
#
# Start Round 4 ...
# client_0: Loss = 0.1708, Accuracy = 0.9498
# client_1: Loss = 0.1652, Accuracy = 0.9528
# client_2: Loss = 0.172, Accuracy = 0.9505
# client_3: Loss = 0.1729, Accuracy = 0.9485
# client_4: Loss = 0.163, Accuracy = 0.9538
# client_5: Loss = 0.1812, Accuracy = 0.9471
# client_6: Loss = 0.1795, Accuracy = 0.9499
# client_7: Loss = 0.1795, Accuracy = 0.9489
# After round 4, train_loss = 0.166, dev_loss = 0.1746, dev_acc = 0.9487
#
# Start Round 5 ...
# client_0: Loss = 0.1412, Accuracy = 0.9591
# client_1: Loss = 0.1386, Accuracy = 0.9634
# client_2: Loss = 0.1418, Accuracy = 0.9581
# client_3: Loss = 0.143, Accuracy = 0.9589
# client_4: Loss = 0.1358, Accuracy = 0.9597
# client_5: Loss = 0.154, Accuracy = 0.9563
# client_6: Loss = 0.1516, Accuracy = 0.9568
# client_7: Loss = 0.1511, Accuracy = 0.9595
# After round 5, train_loss = 0.1404, dev_loss = 0.1486, dev_acc = 0.9572
#
# Start Round 6 ...
# client_0: Loss = 0.1208, Accuracy = 0.9672
# client_1: Loss = 0.1202, Accuracy = 0.9695
# client_2: Loss = 0.1226, Accuracy = 0.9637
# client_3: Loss = 0.1243, Accuracy = 0.964
# client_4: Loss = 0.1207, Accuracy = 0.9646
# client_5: Loss = 0.1334, Accuracy = 0.9635
# client_6: Loss = 0.1323, Accuracy = 0.9643
# client_7: Loss = 0.1308, Accuracy = 0.9633
# After round 6, train_loss = 0.1224, dev_loss = 0.1307, dev_acc = 0.9633
#
# Start Round 7 ...
# client_0: Loss = 0.1063, Accuracy = 0.9694
# client_1: Loss = 0.1056, Accuracy = 0.9728
# client_2: Loss = 0.1088, Accuracy = 0.9702
# client_3: Loss = 0.111, Accuracy = 0.9694
# client_4: Loss = 0.105, Accuracy = 0.9706
# client_5: Loss = 0.1179, Accuracy = 0.9656
# client_6: Loss = 0.1158, Accuracy = 0.9674
# client_7: Loss = 0.1154, Accuracy = 0.9682
# After round 7, train_loss = 0.1098, dev_loss = 0.1173, dev_acc = 0.9645
#
# Start Round 8 ...
# client_0: Loss = 0.0972, Accuracy = 0.9701
# client_1: Loss = 0.0956, Accuracy = 0.9746
# client_2: Loss = 0.0983, Accuracy = 0.9716
# client_3: Loss = 0.099, Accuracy = 0.9712
# client_4: Loss = 0.0962, Accuracy = 0.9726
# client_5: Loss = 0.1059, Accuracy = 0.9716
# client_6: Loss = 0.1065, Accuracy = 0.9694
# client_7: Loss = 0.1027, Accuracy = 0.9719
# After round 8, train_loss = 0.0993, dev_loss = 0.1073, dev_acc = 0.9684
#
# Start Round 9 ...
# client_0: Loss = 0.0899, Accuracy = 0.9743
# client_1: Loss = 0.087, Accuracy = 0.9773
# client_2: Loss = 0.0899, Accuracy = 0.972
# client_3: Loss = 0.0866, Accuracy = 0.9759
# client_4: Loss = 0.0895, Accuracy = 0.9744
# client_5: Loss = 0.0991, Accuracy = 0.9723
# client_6: Loss = 0.0964, Accuracy = 0.9724
# client_7: Loss = 0.0942, Accuracy = 0.9736
# After round 9, train_loss = 0.091, dev_loss = 0.1001, dev_acc = 0.9702
#
# Start Round 10 ...
# client_0: Loss = 0.082, Accuracy = 0.9777
# client_1: Loss = 0.0819, Accuracy = 0.9772
# client_2: Loss = 0.0833, Accuracy = 0.9755
# client_3: Loss = 0.0804, Accuracy = 0.9761
# client_4: Loss = 0.0834, Accuracy = 0.9756
# client_5: Loss = 0.0897, Accuracy = 0.9751
# client_6: Loss = 0.0919, Accuracy = 0.9741
# client_7: Loss = 0.0895, Accuracy = 0.9751
# After round 10, train_loss = 0.0857, dev_loss = 0.0954, dev_acc = 0.9728
#
# Start Round 11 ...
# client_0: Loss = 0.076, Accuracy = 0.977
# client_1: Loss = 0.0747, Accuracy = 0.9809
# client_2: Loss = 0.0778, Accuracy = 0.9766
# client_3: Loss = 0.0742, Accuracy = 0.9763
# client_4: Loss = 0.0768, Accuracy = 0.977
# client_5: Loss = 0.0843, Accuracy = 0.9773
# client_6: Loss = 0.0841, Accuracy = 0.9762
# client_7: Loss = 0.0816, Accuracy = 0.978
# After round 11, train_loss = 0.0795, dev_loss = 0.0894, dev_acc = 0.9739
#
# Start Round 12 ...
# client_0: Loss = 0.0716, Accuracy = 0.9788
# client_1: Loss = 0.0714, Accuracy = 0.9813
# client_2: Loss = 0.0721, Accuracy = 0.9786
# client_3: Loss = 0.07, Accuracy = 0.9793
# client_4: Loss = 0.0733, Accuracy = 0.9773
# client_5: Loss = 0.0804, Accuracy = 0.9761
# client_6: Loss = 0.0786, Accuracy = 0.9785
# client_7: Loss = 0.0772, Accuracy = 0.9797
# After round 12, train_loss = 0.0756, dev_loss = 0.0862, dev_acc = 0.976
#
# Start Round 13 ...
# client_0: Loss = 0.0681, Accuracy = 0.9785
# client_1: Loss = 0.0675, Accuracy = 0.9832
# client_2: Loss = 0.0679, Accuracy = 0.9799
# client_3: Loss = 0.0667, Accuracy = 0.9805
# client_4: Loss = 0.0693, Accuracy = 0.9791
# client_5: Loss = 0.0747, Accuracy = 0.98
# client_6: Loss = 0.076, Accuracy = 0.9774
# client_7: Loss = 0.0727, Accuracy = 0.9773
# After round 13, train_loss = 0.0713, dev_loss = 0.0827, dev_acc = 0.9768
#
# Start Round 14 ...
# client_0: Loss = 0.0646, Accuracy = 0.9822
# client_1: Loss = 0.0646, Accuracy = 0.9821
# client_2: Loss = 0.0645, Accuracy = 0.9816
# client_3: Loss = 0.0636, Accuracy = 0.9819
# client_4: Loss = 0.0676, Accuracy = 0.98
# client_5: Loss = 0.0716, Accuracy = 0.9783
# client_6: Loss = 0.0728, Accuracy = 0.9791
# client_7: Loss = 0.0706, Accuracy = 0.9793
# After round 14, train_loss = 0.0685, dev_loss = 0.0799, dev_acc = 0.9772
#
# Start Round 15 ...
# client_0: Loss = 0.0615, Accuracy = 0.9811
# client_1: Loss = 0.0631, Accuracy = 0.9825
# client_2: Loss = 0.0627, Accuracy = 0.9826
# client_3: Loss = 0.0599, Accuracy = 0.9819
# client_4: Loss = 0.0626, Accuracy = 0.9808
# client_5: Loss = 0.0675, Accuracy = 0.982
# client_6: Loss = 0.0695, Accuracy = 0.9788
# client_7: Loss = 0.0656, Accuracy = 0.9817
# After round 15, train_loss = 0.0655, dev_loss = 0.0781, dev_acc = 0.9785
#
# Start Round 16 ...
# client_0: Loss = 0.059, Accuracy = 0.983
# client_1: Loss = 0.0608, Accuracy = 0.9842
# client_2: Loss = 0.059, Accuracy = 0.983
# client_3: Loss = 0.0588, Accuracy = 0.982
# client_4: Loss = 0.0604, Accuracy = 0.9824
# client_5: Loss = 0.0648, Accuracy = 0.9807
# client_6: Loss = 0.0656, Accuracy = 0.9791
# client_7: Loss = 0.062, Accuracy = 0.9824
# After round 16, train_loss = 0.0622, dev_loss = 0.0747, dev_acc = 0.9787
#
# Start Round 17 ...
# client_0: Loss = 0.0562, Accuracy = 0.9828
# client_1: Loss = 0.057, Accuracy = 0.9839
# client_2: Loss = 0.0586, Accuracy = 0.9829
# client_3: Loss = 0.0552, Accuracy = 0.984
# client_4: Loss = 0.0576, Accuracy = 0.9823
# client_5: Loss = 0.063, Accuracy = 0.9807
# client_6: Loss = 0.0627, Accuracy = 0.9808
# client_7: Loss = 0.0609, Accuracy = 0.9851
# After round 17, train_loss = 0.0599, dev_loss = 0.073, dev_acc = 0.9792
#
# Start Round 18 ...
# client_0: Loss = 0.0533, Accuracy = 0.9853
# client_1: Loss = 0.0548, Accuracy = 0.985
# client_2: Loss = 0.0549, Accuracy = 0.9834
# client_3: Loss = 0.0529, Accuracy = 0.9836
# client_4: Loss = 0.0568, Accuracy = 0.982
# client_5: Loss = 0.0598, Accuracy = 0.9839
# client_6: Loss = 0.0607, Accuracy = 0.9816
# client_7: Loss = 0.0584, Accuracy = 0.9828
# After round 18, train_loss = 0.058, dev_loss = 0.0717, dev_acc = 0.9793
#
# Start Round 19 ...
# client_0: Loss = 0.0519, Accuracy = 0.9849
# client_1: Loss = 0.0526, Accuracy = 0.9853
# client_2: Loss = 0.0527, Accuracy = 0.9851
# client_3: Loss = 0.05, Accuracy = 0.9861
# client_4: Loss = 0.0539, Accuracy = 0.9828
# client_5: Loss = 0.057, Accuracy = 0.9841
# client_6: Loss = 0.0588, Accuracy = 0.9822
# client_7: Loss = 0.057, Accuracy = 0.9842
# After round 19, train_loss = 0.0564, dev_loss = 0.0709, dev_acc = 0.9798
#
# Start Round 20 ...
# client_0: Loss = 0.0497, Accuracy = 0.9849
# client_1: Loss = 0.0512, Accuracy = 0.9849
# client_2: Loss = 0.0502, Accuracy = 0.9859
# client_3: Loss = 0.0482, Accuracy = 0.9857
# client_4: Loss = 0.0522, Accuracy = 0.9845
# client_5: Loss = 0.0547, Accuracy = 0.9843
# client_6: Loss = 0.0561, Accuracy = 0.9827
# client_7: Loss = 0.055, Accuracy = 0.9848
# After round 20, train_loss = 0.0548, dev_loss = 0.0698, dev_acc = 0.9798
#
# Start Round 21 ...
# client_0: Loss = 0.0483, Accuracy = 0.9851
# client_1: Loss = 0.0509, Accuracy = 0.9864
# client_2: Loss = 0.0498, Accuracy = 0.9865
# client_3: Loss = 0.0476, Accuracy = 0.9847
# client_4: Loss = 0.0512, Accuracy = 0.9853
# client_5: Loss = 0.0535, Accuracy = 0.9864
# client_6: Loss = 0.0536, Accuracy = 0.9832
# client_7: Loss = 0.053, Accuracy = 0.9857
# After round 21, train_loss = 0.0532, dev_loss = 0.069, dev_acc = 0.9801
#
# Start Round 22 ...
# client_0: Loss = 0.047, Accuracy = 0.9863
# client_1: Loss = 0.0494, Accuracy = 0.9861
# client_2: Loss = 0.0465, Accuracy = 0.9879
# client_3: Loss = 0.0451, Accuracy = 0.9857
# client_4: Loss = 0.0491, Accuracy = 0.9867
# client_5: Loss = 0.0511, Accuracy = 0.9863
# client_6: Loss = 0.0537, Accuracy = 0.9831
# client_7: Loss = 0.0497, Accuracy = 0.9864
# After round 22, train_loss = 0.0508, dev_loss = 0.0664, dev_acc = 0.9809
#
# Start Round 23 ...
# client_0: Loss = 0.046, Accuracy = 0.9872
# client_1: Loss = 0.0457, Accuracy = 0.9864
# client_2: Loss = 0.0478, Accuracy = 0.9862
# client_3: Loss = 0.0434, Accuracy = 0.9864
# client_4: Loss = 0.0475, Accuracy = 0.9876
# client_5: Loss = 0.0501, Accuracy = 0.9858
# client_6: Loss = 0.0532, Accuracy = 0.9831
# client_7: Loss = 0.0471, Accuracy = 0.9872
# After round 23, train_loss = 0.0494, dev_loss = 0.0651, dev_acc = 0.9814
#
# Start Round 24 ...
# client_0: Loss = 0.0441, Accuracy = 0.9864
# client_1: Loss = 0.0455, Accuracy = 0.9866
# client_2: Loss = 0.0445, Accuracy = 0.9873
# client_3: Loss = 0.0429, Accuracy = 0.9864
# client_4: Loss = 0.0461, Accuracy = 0.9856
# client_5: Loss = 0.0471, Accuracy = 0.9871
# client_6: Loss = 0.049, Accuracy = 0.985
# client_7: Loss = 0.0462, Accuracy = 0.9883
# After round 24, train_loss = 0.0488, dev_loss = 0.0646, dev_acc = 0.9804
#
# Start Round 25 ...
# client_0: Loss = 0.043, Accuracy = 0.9872
# client_1: Loss = 0.0446, Accuracy = 0.9863
# client_2: Loss = 0.0442, Accuracy = 0.9874
# client_3: Loss = 0.0421, Accuracy = 0.9862
# client_4: Loss = 0.0455, Accuracy = 0.9867
# client_5: Loss = 0.0484, Accuracy = 0.9864
# client_6: Loss = 0.047, Accuracy = 0.9857
# client_7: Loss = 0.045, Accuracy = 0.9881
# After round 25, train_loss = 0.0466, dev_loss = 0.0632, dev_acc = 0.9818
#
# Start Round 26 ...
# client_0: Loss = 0.042, Accuracy = 0.9878
# client_1: Loss = 0.0439, Accuracy = 0.9879
# client_2: Loss = 0.0418, Accuracy = 0.9884
# client_3: Loss = 0.0401, Accuracy = 0.9883
# client_4: Loss = 0.0431, Accuracy = 0.9872
# client_5: Loss = 0.0443, Accuracy = 0.9877
# client_6: Loss = 0.0448, Accuracy = 0.988
# client_7: Loss = 0.044, Accuracy = 0.9884
# After round 26, train_loss = 0.0458, dev_loss = 0.0626, dev_acc = 0.9817
#
# Start Round 27 ...
# client_0: Loss = 0.0406, Accuracy = 0.9873
# client_1: Loss = 0.0438, Accuracy = 0.9877
# client_2: Loss = 0.0409, Accuracy = 0.9873
# client_3: Loss = 0.0389, Accuracy = 0.9881
# client_4: Loss = 0.0435, Accuracy = 0.9867
# client_5: Loss = 0.0432, Accuracy = 0.9878
# client_6: Loss = 0.0433, Accuracy = 0.9864
# client_7: Loss = 0.0418, Accuracy = 0.99
# After round 27, train_loss = 0.0445, dev_loss = 0.0618, dev_acc = 0.9823
#
# Start Round 28 ...
# client_0: Loss = 0.0376, Accuracy = 0.99
# client_1: Loss = 0.0416, Accuracy = 0.9889
# client_2: Loss = 0.0399, Accuracy = 0.9895
# client_3: Loss = 0.0381, Accuracy = 0.9885
# client_4: Loss = 0.0409, Accuracy = 0.9878
# client_5: Loss = 0.0429, Accuracy = 0.9874
# client_6: Loss = 0.042, Accuracy = 0.9877
# client_7: Loss = 0.0411, Accuracy = 0.9887
# After round 28, train_loss = 0.0438, dev_loss = 0.0615, dev_acc = 0.982
#
# Start Round 29 ...
# client_0: Loss = 0.0371, Accuracy = 0.9896
# client_1: Loss = 0.0391, Accuracy = 0.9892
# client_2: Loss = 0.0383, Accuracy = 0.9901
# client_3: Loss = 0.0369, Accuracy = 0.9888
# client_4: Loss = 0.0411, Accuracy = 0.9877
# client_5: Loss = 0.0412, Accuracy = 0.989
# client_6: Loss = 0.0415, Accuracy = 0.9885
# client_7: Loss = 0.0409, Accuracy = 0.9896
# After round 29, train_loss = 0.0426, dev_loss = 0.0614, dev_acc = 0.983
#
# Start Round 30 ...
# client_0: Loss = 0.036, Accuracy = 0.9902
# client_1: Loss = 0.04, Accuracy = 0.9888
# client_2: Loss = 0.0387, Accuracy = 0.9895
# client_3: Loss = 0.0358, Accuracy = 0.9895
# client_4: Loss = 0.0393, Accuracy = 0.9879
# client_5: Loss = 0.0402, Accuracy = 0.9892
# client_6: Loss = 0.0388, Accuracy = 0.9887
# client_7: Loss = 0.0391, Accuracy = 0.9895
# After round 30, train_loss = 0.0412, dev_loss = 0.06, dev_acc = 0.9824

# %%
plt.plot([i + 1 for i in range(len(history))], [history[i][0] for i in range(len(history))], color='r', label='train loss')
plt.plot([i + 1 for i in range(len(history))], [history[i][1] for i in range(len(history))], color='b', label='dev loss')
plt.legend()
plt.title('Training history')
plt.show()
