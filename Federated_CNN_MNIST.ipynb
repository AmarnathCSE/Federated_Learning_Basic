# %%
import torch
from torchvision.datasets import MNIST
from torch.utils.data import random_split, DataLoader
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [5, 5]

# %%
train_dataset = MNIST(root='./data', train=True, download=True, transform=transforms.ToTensor())
test_dataset = MNIST(root='./data', train=False, download=True, transform=transforms.ToTensor())

train_dataset, dev_dataset = random_split(train_dataset, [int(len(train_dataset) * 0.83), int(len(train_dataset) * 0.17)])

# %%
total_train_size = len(train_dataset)
total_test_size = len(test_dataset)
total_dev_size = len(dev_dataset)

classes = 10
input_dim = 784

num_clients = 8
rounds = 30
batch_size = 128
epochs_per_client = 3
learning_rate = 2e-2

# %%
total_train_size, total_dev_size, total_test_size
# Out:
# (49800, 10200, 10000)

# %%
def get_device():
    return torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

def to_device(data, device):
    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader(DataLoader):
        def __init__(self, dl, device):
            self.dl = dl
            self.device = device

        def __iter__(self):
            for batch in self.dl:
                yield to_device(batch, self.device)

        def __len__(self):
          return len(self.dl)

device = get_device()

# %%
class FederatedNet(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = torch.nn.Conv2d(1, 20, 7)
        self.conv2 = torch.nn.Conv2d(20, 40, 7)
        self.maxpool = torch.nn.MaxPool2d(2, 2)
        self.flatten = torch.nn.Flatten()
        self.linear = torch.nn.Linear(2560, 10)
        self.non_linearity = torch.nn.functional.relu
        self.track_layers = {'conv1': self.conv1, 'conv2': self.conv2, 'linear': self.linear}
    def forward(self, x_batch):
        out = self.conv1(x_batch)
        out = self.non_linearity(out)
        out = self.conv2(out)
        out = self.non_linearity(out)
        out = self.maxpool(out)
        out = self.flatten(out)
        out = self.linear(out)
        return out

    def get_track_layers(self):
        return self.track_layers

    def apply_parameters(self, parameters_dict):
        with torch.no_grad():
            for layer_name in parameters_dict:
                self.track_layers[layer_name].weight.data *= 0
                self.track_layers[layer_name].bias.data *= 0
                self.track_layers[layer_name].weight.data += parameters_dict[layer_name]['weight']
                self.track_layers[layer_name].bias.data += parameters_dict[layer_name]['bias']

    def get_parameters(self):
        parameters_dict = dict()
        for layer_name in self.track_layers:
            parameters_dict[layer_name] = {
                'weight': self.track_layers[layer_name].weight.data,
                'bias': self.track_layers[layer_name].bias.data
            }
        return parameters_dict

    def batch_accuracy(self, outputs, labels):
        with torch.no_grad():
            _, predictions = torch.max(outputs, dim=1)
            return torch.tensor(torch.sum(predictions == labels).item() / len(predictions))

    def _process_batch(self, batch):
        images, labels = batch
        outputs = self(images)
        loss = torch.nn.functional.cross_entropy(outputs, labels)
        accuracy = self.batch_accuracy(outputs, labels)
        return (loss, accuracy)

    def fit(self, dataset, epochs, lr, batch_size=128, opt=torch.optim.SGD):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size, shuffle=True), device)
        optimizer = opt(self.parameters(), lr)
        history = []
        for epoch in range(epochs):
            losses = []
            accs = []
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                loss.backward()
                optimizer.step()
                optimizer.zero_grad()
                loss.detach()
                losses.append(loss)
                accs.append(acc)
            avg_loss = torch.stack(losses).mean().item()
            avg_acc = torch.stack(accs).mean().item()
            history.append((avg_loss, avg_acc))
        return history

    def evaluate(self, dataset, batch_size=128):
        dataloader = DeviceDataLoader(DataLoader(dataset, batch_size), device)
        losses = []
        accs = []
        with torch.no_grad():
            for batch in dataloader:
                loss, acc = self._process_batch(batch)
                losses.append(loss)
                accs.append(acc)
        avg_loss = torch.stack(losses).mean().item()
        avg_acc = torch.stack(accs).mean().item()
        return (avg_loss, avg_acc)

# %%
class Client:
    def __init__(self, client_id, dataset):
        self.client_id = client_id
        self.dataset = dataset

    def get_dataset_size(self):
        return len(self.dataset)

    def get_client_id(self):
        return self.client_id

    def train(self, parameters_dict):
        net = to_device(FederatedNet(), device)
        net.apply_parameters(parameters_dict)
        train_history = net.fit(self.dataset, epochs_per_client, learning_rate, batch_size)
        print('{}: Loss = {}, Accuracy = {}'.format(self.client_id, round(train_history[-1][0], 4), round(train_history[-1][1], 4)))
        return net.get_parameters()

# %%
examples_per_client = total_train_size // num_clients
client_datasets = random_split(train_dataset, [min(i + examples_per_client,
           total_train_size) - i for i in range(0, total_train_size, examples_per_client)])
clients = [Client('client_' + str(i), client_datasets[i]) for i in range(num_clients)]

# %%
global_net = to_device(FederatedNet(), device)
history = []
for i in range(rounds):
    print('Start Round {} ...'.format(i + 1))
    curr_parameters = global_net.get_parameters()
    new_parameters = dict([(layer_name, {'weight': 0, 'bias': 0}) for layer_name in curr_parameters])
    for client in clients:
        client_parameters = client.train(curr_parameters)
        fraction = client.get_dataset_size() / total_train_size
        for layer_name in client_parameters:
            new_parameters[layer_name]['weight'] += fraction * client_parameters[layer_name]['weight']
            new_parameters[layer_name]['bias'] += fraction * client_parameters[layer_name]['bias']
    global_net.apply_parameters(new_parameters)

    train_loss, train_acc = global_net.evaluate(train_dataset)
    dev_loss, dev_acc = global_net.evaluate(dev_dataset)
    print('After round {}, train_loss = {}, dev_loss = {}, dev_acc = {}\n'.format(i + 1, round(train_loss, 4),
            round(dev_loss, 4), round(dev_acc, 4)))
    history.append((train_loss, dev_loss))
# Out:
# Start Round 1 ...
# client_0: Loss = 0.4745, Accuracy = 0.8503
# client_1: Loss = 0.5134, Accuracy = 0.8471
# client_2: Loss = 0.5079, Accuracy = 0.8456
# client_3: Loss = 0.5086, Accuracy = 0.8425
# client_4: Loss = 0.5345, Accuracy = 0.8424
# client_5: Loss = 0.4775, Accuracy = 0.8541
# client_6: Loss = 0.5027, Accuracy = 0.8521
# client_7: Loss = 0.5071, Accuracy = 0.8503
# After round 1, train_loss = 0.4179, dev_loss = 0.4077, dev_acc = 0.8827
#
# Start Round 2 ...
# client_0: Loss = 0.2977, Accuracy = 0.9124
# client_1: Loss = 0.3231, Accuracy = 0.9076
# client_2: Loss = 0.3288, Accuracy = 0.9024
# client_3: Loss = 0.3241, Accuracy = 0.9031
# client_4: Loss = 0.3318, Accuracy = 0.9037
# client_5: Loss = 0.2978, Accuracy = 0.9119
# client_6: Loss = 0.3332, Accuracy = 0.9011
# client_7: Loss = 0.3185, Accuracy = 0.906
# After round 2, train_loss = 0.2917, dev_loss = 0.2831, dev_acc = 0.9191
#
# Start Round 3 ...
# client_0: Loss = 0.2073, Accuracy = 0.9435
# client_1: Loss = 0.2419, Accuracy = 0.93
# client_2: Loss = 0.2449, Accuracy = 0.9308
# client_3: Loss = 0.2377, Accuracy = 0.9314
# client_4: Loss = 0.243, Accuracy = 0.9283
# client_5: Loss = 0.2146, Accuracy = 0.9362
# client_6: Loss = 0.2523, Accuracy = 0.9279
# client_7: Loss = 0.2348, Accuracy = 0.9322
# After round 3, train_loss = 0.2192, dev_loss = 0.2133, dev_acc = 0.9392
#
# Start Round 4 ...
# client_0: Loss = 0.1607, Accuracy = 0.957
# client_1: Loss = 0.1886, Accuracy = 0.9443
# client_2: Loss = 0.1863, Accuracy = 0.948
# client_3: Loss = 0.1818, Accuracy = 0.9472
# client_4: Loss = 0.1865, Accuracy = 0.9454
# client_5: Loss = 0.1615, Accuracy = 0.951
# client_6: Loss = 0.2002, Accuracy = 0.9423
# client_7: Loss = 0.1791, Accuracy = 0.9479
# After round 4, train_loss = 0.1733, dev_loss = 0.1703, dev_acc = 0.9528
#
# Start Round 5 ...
# client_0: Loss = 0.1292, Accuracy = 0.9645
# client_1: Loss = 0.1565, Accuracy = 0.9542
# client_2: Loss = 0.1553, Accuracy = 0.9548
# client_3: Loss = 0.1517, Accuracy = 0.9555
# client_4: Loss = 0.1516, Accuracy = 0.956
# client_5: Loss = 0.1303, Accuracy = 0.9618
# client_6: Loss = 0.1628, Accuracy = 0.9551
# client_7: Loss = 0.1496, Accuracy = 0.9567
# After round 5, train_loss = 0.143, dev_loss = 0.1426, dev_acc = 0.9604
#
# Start Round 6 ...
# client_0: Loss = 0.1113, Accuracy = 0.9677
# client_1: Loss = 0.1333, Accuracy = 0.9612
# client_2: Loss = 0.1326, Accuracy = 0.9618
# client_3: Loss = 0.1305, Accuracy = 0.9626
# client_4: Loss = 0.1279, Accuracy = 0.9623
# client_5: Loss = 0.1125, Accuracy = 0.9654
# client_6: Loss = 0.1387, Accuracy = 0.9623
# client_7: Loss = 0.1257, Accuracy = 0.9646
# After round 6, train_loss = 0.1231, dev_loss = 0.1238, dev_acc = 0.966
#
# Start Round 7 ...
# client_0: Loss = 0.0967, Accuracy = 0.9738
# client_1: Loss = 0.1188, Accuracy = 0.9658
# client_2: Loss = 0.1166, Accuracy = 0.9667
# client_3: Loss = 0.1125, Accuracy = 0.9693
# client_4: Loss = 0.1123, Accuracy = 0.969
# client_5: Loss = 0.0953, Accuracy = 0.9724
# client_6: Loss = 0.1256, Accuracy = 0.9656
# client_7: Loss = 0.111, Accuracy = 0.9693
# After round 7, train_loss = 0.1104, dev_loss = 0.1125, dev_acc = 0.9689
#
# Start Round 8 ...
# client_0: Loss = 0.0864, Accuracy = 0.9788
# client_1: Loss = 0.1062, Accuracy = 0.9685
# client_2: Loss = 0.108, Accuracy = 0.9688
# client_3: Loss = 0.1026, Accuracy = 0.9705
# client_4: Loss = 0.0995, Accuracy = 0.972
# client_5: Loss = 0.0845, Accuracy = 0.9752
# client_6: Loss = 0.1137, Accuracy = 0.9664
# client_7: Loss = 0.099, Accuracy = 0.9702
# After round 8, train_loss = 0.0991, dev_loss = 0.1027, dev_acc = 0.9704
#
# Start Round 9 ...
# client_0: Loss = 0.0775, Accuracy = 0.9782
# client_1: Loss = 0.0978, Accuracy = 0.9725
# client_2: Loss = 0.0978, Accuracy = 0.9713
# client_3: Loss = 0.0943, Accuracy = 0.9737
# client_4: Loss = 0.0926, Accuracy = 0.975
# client_5: Loss = 0.0752, Accuracy = 0.9789
# client_6: Loss = 0.1066, Accuracy = 0.9694
# client_7: Loss = 0.0885, Accuracy = 0.9742
# After round 9, train_loss = 0.0909, dev_loss = 0.0959, dev_acc = 0.9724
#
# Start Round 10 ...
# client_0: Loss = 0.0745, Accuracy = 0.9778
# client_1: Loss = 0.0888, Accuracy = 0.9742
# client_2: Loss = 0.0899, Accuracy = 0.9733
# client_3: Loss = 0.0879, Accuracy = 0.9753
# client_4: Loss = 0.0847, Accuracy = 0.976
# client_5: Loss = 0.0705, Accuracy = 0.978
# client_6: Loss = 0.0967, Accuracy = 0.9738
# client_7: Loss = 0.0812, Accuracy = 0.9768
# After round 10, train_loss = 0.0844, dev_loss = 0.0899, dev_acc = 0.9733
#
# Start Round 11 ...
# client_0: Loss = 0.0689, Accuracy = 0.9793
# client_1: Loss = 0.0844, Accuracy = 0.9756
# client_2: Loss = 0.0849, Accuracy = 0.9761
# client_3: Loss = 0.0844, Accuracy = 0.9757
# client_4: Loss = 0.0778, Accuracy = 0.9783
# client_5: Loss = 0.0636, Accuracy = 0.9804
# client_6: Loss = 0.0897, Accuracy = 0.9754
# client_7: Loss = 0.0762, Accuracy = 0.9772
# After round 11, train_loss = 0.0792, dev_loss = 0.0861, dev_acc = 0.9753
#
# Start Round 12 ...
# client_0: Loss = 0.0625, Accuracy = 0.9814
# client_1: Loss = 0.0812, Accuracy = 0.9761
# client_2: Loss = 0.0812, Accuracy = 0.9761
# client_3: Loss = 0.0795, Accuracy = 0.9769
# client_4: Loss = 0.072, Accuracy = 0.9793
# client_5: Loss = 0.0614, Accuracy = 0.9824
# client_6: Loss = 0.0852, Accuracy = 0.9755
# client_7: Loss = 0.0696, Accuracy = 0.9788
# After round 12, train_loss = 0.0749, dev_loss = 0.0824, dev_acc = 0.9758
#
# Start Round 13 ...
# client_0: Loss = 0.0594, Accuracy = 0.9815
# client_1: Loss = 0.0749, Accuracy = 0.9785
# client_2: Loss = 0.0746, Accuracy = 0.9776
# client_3: Loss = 0.0751, Accuracy = 0.9784
# client_4: Loss = 0.0678, Accuracy = 0.9804
# client_5: Loss = 0.0561, Accuracy = 0.9839
# client_6: Loss = 0.0803, Accuracy = 0.9771
# client_7: Loss = 0.0661, Accuracy = 0.9813
# After round 13, train_loss = 0.0709, dev_loss = 0.0784, dev_acc = 0.9768
#
# Start Round 14 ...
# client_0: Loss = 0.0565, Accuracy = 0.9839
# client_1: Loss = 0.0711, Accuracy = 0.9797
# client_2: Loss = 0.0712, Accuracy = 0.9786
# client_3: Loss = 0.071, Accuracy = 0.9798
# client_4: Loss = 0.0631, Accuracy = 0.9812
# client_5: Loss = 0.0541, Accuracy = 0.984
# client_6: Loss = 0.0782, Accuracy = 0.978
# client_7: Loss = 0.0622, Accuracy = 0.9818
# After round 14, train_loss = 0.0676, dev_loss = 0.0759, dev_acc = 0.9775
#
# Start Round 15 ...
# client_0: Loss = 0.0533, Accuracy = 0.9835
# client_1: Loss = 0.0691, Accuracy = 0.9787
# client_2: Loss = 0.0662, Accuracy = 0.9811
# client_3: Loss = 0.0685, Accuracy = 0.98
# client_4: Loss = 0.0618, Accuracy = 0.9828
# client_5: Loss = 0.0489, Accuracy = 0.9875
# client_6: Loss = 0.0714, Accuracy = 0.98
# client_7: Loss = 0.0586, Accuracy = 0.9839
# After round 15, train_loss = 0.0647, dev_loss = 0.0741, dev_acc = 0.9775
#
# Start Round 16 ...
# client_0: Loss = 0.0504, Accuracy = 0.9851
# client_1: Loss = 0.0662, Accuracy = 0.9817
# client_2: Loss = 0.0668, Accuracy = 0.9792
# client_3: Loss = 0.0642, Accuracy = 0.9821
# client_4: Loss = 0.0575, Accuracy = 0.9828
# client_5: Loss = 0.0473, Accuracy = 0.9866
# client_6: Loss = 0.0697, Accuracy = 0.9807
# client_7: Loss = 0.0559, Accuracy = 0.9843
# After round 16, train_loss = 0.0616, dev_loss = 0.0711, dev_acc = 0.9795
#
# Start Round 17 ...
# client_0: Loss = 0.0474, Accuracy = 0.9868
# client_1: Loss = 0.0621, Accuracy = 0.9817
# client_2: Loss = 0.0637, Accuracy = 0.9812
# client_3: Loss = 0.0624, Accuracy = 0.9823
# client_4: Loss = 0.0558, Accuracy = 0.9838
# client_5: Loss = 0.0451, Accuracy = 0.9883
# client_6: Loss = 0.0647, Accuracy = 0.9808
# client_7: Loss = 0.0524, Accuracy = 0.9851
# After round 17, train_loss = 0.0593, dev_loss = 0.0689, dev_acc = 0.9802
#
# Start Round 18 ...
# client_0: Loss = 0.0466, Accuracy = 0.9859
# client_1: Loss = 0.0616, Accuracy = 0.9823
# client_2: Loss = 0.0626, Accuracy = 0.9811
# client_3: Loss = 0.0612, Accuracy = 0.9828
# client_4: Loss = 0.0535, Accuracy = 0.9822
# client_5: Loss = 0.0426, Accuracy = 0.9884
# client_6: Loss = 0.0636, Accuracy = 0.9814
# client_7: Loss = 0.0509, Accuracy = 0.9856
# After round 18, train_loss = 0.0574, dev_loss = 0.0671, dev_acc = 0.9806
#
# Start Round 19 ...
# client_0: Loss = 0.0448, Accuracy = 0.9867
# client_1: Loss = 0.0584, Accuracy = 0.9832
# client_2: Loss = 0.06, Accuracy = 0.9817
# client_3: Loss = 0.0605, Accuracy = 0.9826
# client_4: Loss = 0.0513, Accuracy = 0.9843
# client_5: Loss = 0.0418, Accuracy = 0.9885
# client_6: Loss = 0.0626, Accuracy = 0.9805
# client_7: Loss = 0.0482, Accuracy = 0.9856
# After round 19, train_loss = 0.0554, dev_loss = 0.0655, dev_acc = 0.9808
#
# Start Round 20 ...
# client_0: Loss = 0.0417, Accuracy = 0.9877
# client_1: Loss = 0.0569, Accuracy = 0.9833
# client_2: Loss = 0.0579, Accuracy = 0.9827
# client_3: Loss = 0.0582, Accuracy = 0.9845
# client_4: Loss = 0.0496, Accuracy = 0.9857
# client_5: Loss = 0.0384, Accuracy = 0.99
# client_6: Loss = 0.0587, Accuracy = 0.9833
# client_7: Loss = 0.0468, Accuracy = 0.987
# After round 20, train_loss = 0.0535, dev_loss = 0.0641, dev_acc = 0.9816
#
# Start Round 21 ...
# client_0: Loss = 0.0404, Accuracy = 0.9885
# client_1: Loss = 0.0552, Accuracy = 0.9851
# client_2: Loss = 0.0544, Accuracy = 0.9839
# client_3: Loss = 0.0543, Accuracy = 0.9852
# client_4: Loss = 0.047, Accuracy = 0.9849
# client_5: Loss = 0.0387, Accuracy = 0.9892
# client_6: Loss = 0.0567, Accuracy = 0.9838
# client_7: Loss = 0.0453, Accuracy = 0.9872
# After round 21, train_loss = 0.0519, dev_loss = 0.0631, dev_acc = 0.9817
#
# Start Round 22 ...
# client_0: Loss = 0.0401, Accuracy = 0.9896
# client_1: Loss = 0.0531, Accuracy = 0.9847
# client_2: Loss = 0.0543, Accuracy = 0.9847
# client_3: Loss = 0.0539, Accuracy = 0.9855
# client_4: Loss = 0.0452, Accuracy = 0.9864
# client_5: Loss = 0.0354, Accuracy = 0.9895
# client_6: Loss = 0.0545, Accuracy = 0.9841
# client_7: Loss = 0.043, Accuracy = 0.9891
# After round 22, train_loss = 0.0504, dev_loss = 0.0621, dev_acc = 0.9823
#
# Start Round 23 ...
# client_0: Loss = 0.0372, Accuracy = 0.9894
# client_1: Loss = 0.0512, Accuracy = 0.9863
# client_2: Loss = 0.052, Accuracy = 0.984
# client_3: Loss = 0.0527, Accuracy = 0.9853
# client_4: Loss = 0.0421, Accuracy = 0.9866
# client_5: Loss = 0.0362, Accuracy = 0.9902
# client_6: Loss = 0.0524, Accuracy = 0.9853
# client_7: Loss = 0.0418, Accuracy = 0.9872
# After round 23, train_loss = 0.0491, dev_loss = 0.0608, dev_acc = 0.9824
#
# Start Round 24 ...
# client_0: Loss = 0.0373, Accuracy = 0.9893
# client_1: Loss = 0.0497, Accuracy = 0.9866
# client_2: Loss = 0.0512, Accuracy = 0.984
# client_3: Loss = 0.0517, Accuracy = 0.9849
# client_4: Loss = 0.0417, Accuracy = 0.9879
# client_5: Loss = 0.0342, Accuracy = 0.9903
# client_6: Loss = 0.0515, Accuracy = 0.9852
# client_7: Loss = 0.0391, Accuracy = 0.9915
# After round 24, train_loss = 0.0477, dev_loss = 0.0598, dev_acc = 0.9835
#
# Start Round 25 ...
# client_0: Loss = 0.0354, Accuracy = 0.9911
# client_1: Loss = 0.0483, Accuracy = 0.9867
# client_2: Loss = 0.0478, Accuracy = 0.9853
# client_3: Loss = 0.0517, Accuracy = 0.9857
# client_4: Loss = 0.04, Accuracy = 0.9883
# client_5: Loss = 0.0336, Accuracy = 0.9902
# client_6: Loss = 0.0508, Accuracy = 0.9855
# client_7: Loss = 0.0386, Accuracy = 0.9899
# After round 25, train_loss = 0.0469, dev_loss = 0.0594, dev_acc = 0.9832
#
# Start Round 26 ...
# client_0: Loss = 0.0333, Accuracy = 0.9901
# client_1: Loss = 0.0467, Accuracy = 0.9877
# client_2: Loss = 0.0475, Accuracy = 0.9849
# client_3: Loss = 0.0492, Accuracy = 0.9856
# client_4: Loss = 0.0387, Accuracy = 0.9872
# client_5: Loss = 0.0326, Accuracy = 0.9905
# client_6: Loss = 0.0486, Accuracy = 0.9853
# client_7: Loss = 0.0364, Accuracy = 0.9902
# After round 26, train_loss = 0.0454, dev_loss = 0.0579, dev_acc = 0.9833
#
# Start Round 27 ...
# client_0: Loss = 0.0332, Accuracy = 0.9903
# client_1: Loss = 0.0459, Accuracy = 0.9879
# client_2: Loss = 0.0475, Accuracy = 0.9852
# client_3: Loss = 0.0467, Accuracy = 0.9873
# client_4: Loss = 0.0385, Accuracy = 0.988
# client_5: Loss = 0.0312, Accuracy = 0.9914
# client_6: Loss = 0.0475, Accuracy = 0.9873
# client_7: Loss = 0.0358, Accuracy = 0.9923
# After round 27, train_loss = 0.0442, dev_loss = 0.0575, dev_acc = 0.9832
#
# Start Round 28 ...
# client_0: Loss = 0.0302, Accuracy = 0.9911
# client_1: Loss = 0.0454, Accuracy = 0.9883
# client_2: Loss = 0.0471, Accuracy = 0.9859
# client_3: Loss = 0.0466, Accuracy = 0.9875
# client_4: Loss = 0.0365, Accuracy = 0.9883
# client_5: Loss = 0.0305, Accuracy = 0.9915
# client_6: Loss = 0.0453, Accuracy = 0.9874
# client_7: Loss = 0.0351, Accuracy = 0.9903
# After round 28, train_loss = 0.0432, dev_loss = 0.0568, dev_acc = 0.9837
#
# Start Round 29 ...
# client_0: Loss = 0.0297, Accuracy = 0.9922
# client_1: Loss = 0.0449, Accuracy = 0.9877
# client_2: Loss = 0.0453, Accuracy = 0.9858
# client_3: Loss = 0.047, Accuracy = 0.9861
# client_4: Loss = 0.0352, Accuracy = 0.989
# client_5: Loss = 0.0294, Accuracy = 0.9914
# client_6: Loss = 0.0446, Accuracy = 0.9868
# client_7: Loss = 0.0335, Accuracy = 0.9904
# After round 29, train_loss = 0.0421, dev_loss = 0.0561, dev_acc = 0.9839
#
# Start Round 30 ...
# client_0: Loss = 0.0285, Accuracy = 0.9923
# client_1: Loss = 0.0426, Accuracy = 0.9885
# client_2: Loss = 0.0446, Accuracy = 0.9855
# client_3: Loss = 0.0445, Accuracy = 0.9871
# client_4: Loss = 0.0352, Accuracy = 0.9892
# client_5: Loss = 0.0292, Accuracy = 0.9926
# client_6: Loss = 0.045, Accuracy = 0.9851
# client_7: Loss = 0.0328, Accuracy = 0.991
# After round 30, train_loss = 0.0412, dev_loss = 0.0555, dev_acc = 0.9841

# %%
plt.plot([i + 1 for i in range(len(history))], [history[i][0] for i in range(len(history))], color='r', label='train loss')
plt.plot([i + 1 for i in range(len(history))], [history[i][1] for i in range(len(history))], color='b', label='dev loss')
plt.legend()
plt.title('Training history')
plt.show()
